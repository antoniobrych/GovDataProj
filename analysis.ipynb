# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data_concat//SERMIL_5_ANOS.csv")
# Out:
# /var/folders/t1/8b933_7s62j1hn784572y0wm0000gn/T/ipykernel_27173/3976408502.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data_concat//SERMIL_5_ANOS.csv")

# %%
df['RELIGIAO'].unique()
# Out:
# array([nan, 'Católica', 'Batista', 'Sem Religião', 'Para-Protestante',
#        'Sem Declaração', 'Pentecostal', 'Adventista', 'Afro-Brasileira',
#        'Luterana', 'Ateu', 'Congregacional', 'Espírita',
#        'Religiões Orientais', 'Presbiteriana', 'Anabatistas', 'Ecumênico',
#        'Metodista', 'Islâmica', 'Judaica', 'Budismo', 'Anglicanos',
#        'Esotérica', 'Tradições Indígenas', 'Campbelita', 'Hinduísmo',
#        'Xintoísmo', 'CatÃ³lica', 'Sem ReligiÃ£o', 'Sem DeclaraÃ§Ã£o',
#        'EspÃ\xadrita', 'EsotÃ©rica', 'ReligiÃµes Orientais', 'EcumÃªnico',
#        'IslÃ¢mica', 'TradiÃ§Ãµes IndÃ\xadgenas', 'HinduÃ\xadsmo',
#        'XintoÃ\xadsmo'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24699984 entries, 0 to 24699983
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ANO_NASCIMENTO     float64
#  1   PESO               float64
#  2   ALTURA             float64
#  3   CABECA             float64
#  4   CALCADO            float64
#  5   CINTURA            float64
#  6   RELIGIAO           object
#  7   MUN_NASCIMENTO     object
#  8   UF_NASCIMENTO      object
#  9   PAIS_NASCIMENTO    object
#  10  ESTADO_CIVIL       object
#  11  SEXO               object
#  12  ESCOLARIDADE       object
#  13  VINCULACAO_ANO     int64
#  14  DISPENSA           object
#  15  ZONA_RESIDENCIAL   object
#  16  MUN_RESIDENCIA     object
#  17  UF_RESIDENCIA      object
#  18  PAIS_RESIDENCIA    object
#  19  JSM                object
#  20  MUN_JSM            object
#  21  UF_JSM             object
#  22  ANO_COLETA         int64
#  23  ï»¿ANO_NASCIMENTO  float64
# ...

# %%
df.set_index('ANO_COLETA')['PESO'].dropna().plot()
# Out:
# <Axes: xlabel='ANO_COLETA'>

# %%
df.isna().sum()
# Out:
# ANO_NASCIMENTO        5242324
# PESO                 19108360
# ALTURA               19148090
# CABECA               19110581
# CALCADO              19110105
# CINTURA              19061889
# RELIGIAO             22535908
# MUN_NASCIMENTO              0
# UF_NASCIMENTO               0
# PAIS_NASCIMENTO             0
# ESTADO_CIVIL                0
# SEXO                        0
# ESCOLARIDADE                0
# VINCULACAO_ANO              0
# DISPENSA               474630
# ZONA_RESIDENCIAL            0
# MUN_RESIDENCIA              0
# UF_RESIDENCIA               0
# PAIS_RESIDENCIA             0
# JSM                         0
# MUN_JSM                     0
# UF_JSM                      0
# ANO_COLETA                  0
# ï»¿ANO_NASCIMENTO    19457660
# dtype: int64

# %%
df['TOTAL'].values
# Out:
# array([2007, 2007, 2007, ..., 2022, 2022, 2022])

# %%
df['TOTAL'] = df['ANO_COLETA'].copy()
df[['ANO_COLETA','CINTURA','PESO','ALTURA','TOTAL']].set_index('ANO_COLETA').groupby(level='ANO_COLETA').count()
# Out:
#             CINTURA    PESO  ALTURA    TOTAL
# ANO_COLETA
# 2007         344305  304614  311951  1615993
# 2008         326025  317338  319645  1725059
# 2009         328006  327890  327961  1542705
# 2010         340473  340447  340493  1695573
# 2011         362280  362266  362315  1785369
# 2012         383963  383964  384000  2047103
# 2013         348450  348481  348498  1755442
# 2014         342771  342811  342821  1730941
# 2015         368490  368542  368542  1799865
# 2016         359429  360821  360764  1746671
# 2017         365352  365157  365521  1451502
# 2018         316321  316366  316366   992012
# 2019         407513  408128  358455  1477095
# 2020         415750  415753  415517  1303403
# 2021         328053  328062  328061  1010324
# 2022         300914  300984  300984  1020927

# %%
df[['VINCULACAO_ANO','CINTURA','PESO','ALTURA','SEXO']].set_index('VINCULACAO_ANO').groupby(level='VINCULACAO_ANO').count()
# Out:
#                 CINTURA    PESO  ALTURA     SEXO
# VINCULACAO_ANO
# 2007             344305  304614  311951  1615993
# 2008             326025  317338  319645  1725059
# 2009             328006  327890  327961  1542705
# 2010             340473  340447  340493  1695573
# 2011             362280  362266  362315  1785369
# 2012             383963  383964  384000  2047103
# 2013             348450  348481  348498  1755442
# 2014             342771  342811  342821  1730941
# 2015             368490  368542  368542  1799865
# 2016             359429  360821  360764  1746671
# 2017             365352  365157  365521  1451502
# 2018             316321  316366  316366   992012
# 2019             407513  408128  358455  1477095
# 2020             415750  415753  415517  1303403
# 2021             328053  328062  328061  1010324
# 2022             300914  300984  300984  1020927

# %%
df[['VINCULACAO_ANO','CINTURA','PESO','ALTURA']].set_index('VINCULACAO_ANO').groupby(level='VINCULACAO_ANO').mean()
# Out:
#                   CINTURA       PESO      ALTURA
# VINCULACAO_ANO
# 2007            80.131892  67.523459  173.647724
# 2008            79.973389  67.592614  173.365099
# 2009            80.076361  68.012364  173.783569
# 2010            80.097144  68.522190  173.708969
# 2011            79.899627  68.838878  173.631644
# 2012            80.272003  69.188747  173.719854
# 2013            79.871393  69.492113  173.894525
# 2014            80.053791  69.719140  173.733817
# 2015            80.744965  69.525273  173.536416
# 2016            80.058582  69.344437  173.643166
# 2017            80.809551  69.650961  173.855168
# 2018            78.006335  67.028397  169.928728
# 2019            77.458962  65.214271  173.983663
# 2020            75.485840  63.719829  164.595757
# 2021            78.293392  69.965220  173.542506
# 2022            77.289827  70.127900  174.413201

# %%
synthetic_df = df[['VINCULACAO_ANO','CINTURA','PESO','ALTURA','TOTAL']].set_index('VINCULACAO_ANO').reset_index().set_index('VINCULACAO_ANO').groupby(level='VINCULACAO_ANO').count()

# %%
synthetic_df
# Out:
#                 CINTURA    PESO  ALTURA    TOTAL
# VINCULACAO_ANO
# 2007             344305  304614  311951  1615993
# 2008             326025  317338  319645  1725059
# 2009             328006  327890  327961  1542705
# 2010             340473  340447  340493  1695573
# 2011             362280  362266  362315  1785369
# 2012             383963  383964  384000  2047103
# 2013             348450  348481  348498  1755442
# 2014             342771  342811  342821  1730941
# 2015             368490  368542  368542  1799865
# 2016             359429  360821  360764  1746671
# 2017             365352  365157  365521  1451502
# 2018             316321  316366  316366   992012
# 2019             407513  408128  358455  1477095
# 2020             415750  415753  415517  1303403
# 2021             328053  328062  328061  1010324
# 2022             300914  300984  300984  1020927

# %%
synthetic_df['TOTAL'].plot()
# Out:
# <Axes: xlabel='VINCULACAO_ANO'>

# %%
df[['ANO_','CINTURA','PESO','ALTURA']].set_index('ANO_COLETA').groupby(level='ANO_COLETA').count()
# Out:
#             CINTURA    PESO  ALTURA
# ANO_COLETA
# 2007         344305  304614  311951
# 2008         326025  317338  319645
# 2009         328006  327890  327961
# 2010         340473  340447  340493
# 2011         362280  362266  362315
# 2012         383963  383964  384000
# 2013         348450  348481  348498
# 2014         342771  342811  342821
# 2015         368490  368542  368542
# 2016         359429  360821  360764
# 2017         365352  365157  365521
# 2018         316321  316366  316366
# 2019         407513  408128  358455
# 2020         415750  415753  415517
# 2021         328053  328062  328061
# 2022         300914  300984  300984
